# %%
import warnings; warnings.simplefilter('ignore')
import numpy as np
import pandas as pd
import matplotlib as plt
from sklearn.metrics import mean_squared_error, r2_score


df = pd.read_csv('Concrete_Data.csv')

# rename columns
df.rename(columns=lambda x: x.split('(')[0].strip(), inplace=True)
df= pd.concat([df.iloc[:,:1], df.iloc[:,0]*df.iloc[:,0], df.iloc[:,0]*df.iloc[:,0]*df.iloc[:,0],
               df.iloc[:,1:5], df.iloc[:,4]*df.iloc[:,4], df.iloc[:,4]*df.iloc[:,4]*df.iloc[:,4],
              df.iloc[:,5:8], df.iloc[:,7]*df.iloc[:,7], df.iloc[:,7]*df.iloc[:,7]*df.iloc[:,7],
              df.iloc[:,8:]], axis = 1)

# %%
df.assign().head()
# Out:
#    Cement     Cement        Cement  Blast Furnace Slag  Fly Ash  Water  \
# 0   540.0  291600.00  1.574640e+08                 0.0      0.0  162.0
# 1   540.0  291600.00  1.574640e+08                 0.0      0.0  162.0
# 2   332.5  110556.25  3.675995e+07               142.5      0.0  228.0
# 3   332.5  110556.25  3.675995e+07               142.5      0.0  228.0
# 4   198.6   39441.96  7.833173e+06               132.4      0.0  192.0
#
#    Superplasticizer  Superplasticizer  Superplasticizer  Coarse Aggregate  \
# 0               2.5              6.25            15.625            1040.0
# 1               2.5              6.25            15.625            1055.0
# 2               0.0              0.00             0.000             932.0
# 3               0.0              0.00             0.000             932.0
# 4               0.0              0.00             0.000             978.4
#
#    Fine Aggregate  Age     Age       Age  Concrete compressive strength
# 0           676.0   28     784     21952                          79.99
# 1           676.0   28     784     21952                          61.89
# 2           594.0  270   72900  19683000                          40.27
# 3           594.0  365  133225  48627125                          41.05
# 4           825.5  360  129600  46656000                          44.30

# %%
df.describe(percentiles=[])
# Out:
#             Cement         Cement        Cement  Blast Furnace Slag  \
# count  1030.000000    1030.000000  1.030000e+03         1030.000000
# mean    281.167864   89966.344534  3.201109e+07           73.895825
# std     104.506364   65439.045073  3.432464e+07           86.279342
# min     102.000000   10404.000000  1.061208e+06            0.000000
# 50%     272.900000   74474.420000  2.032407e+07           22.000000
# max     540.000000  291600.000000  1.574640e+08          359.400000
#
#            Fly Ash        Water  Superplasticizer  Superplasticizer  \
# count  1030.000000  1030.000000       1030.000000       1030.000000
# mean     54.188350   181.567282          6.204660         74.149942
# std      63.997004    21.354219          5.973841        120.872811
# min       0.000000   121.800000          0.000000          0.000000
# 50%       0.000000   185.000000          6.400000         40.960000
# max     200.100000   247.000000         32.200000       1036.840000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean        1095.334942        972.918932      773.580485    45.662136
# std         3159.989450         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 50%          262.144000        968.000000      779.500000    28.000000
# max        33386.248000       1145.000000      992.600000   365.000000
#
#                  Age           Age  Concrete compressive strength
# count    1030.000000  1.030000e+03                    1030.000000
# mean     6071.594175  1.462993e+06                      35.817961
# std     20195.954706  6.969770e+06                      16.705742
# min         1.000000  1.000000e+00                       2.330000
# 50%       784.000000  2.195200e+04                      34.445000
# max    133225.000000  4.862712e+07                      82.600000

# %%
df.input=df.iloc[:,0:-1]
df.input.head()
# Out:
#    Cement     Cement        Cement  Blast Furnace Slag  Fly Ash  Water  \
# 0   540.0  291600.00  1.574640e+08                 0.0      0.0  162.0
# 1   540.0  291600.00  1.574640e+08                 0.0      0.0  162.0
# 2   332.5  110556.25  3.675995e+07               142.5      0.0  228.0
# 3   332.5  110556.25  3.675995e+07               142.5      0.0  228.0
# 4   198.6   39441.96  7.833173e+06               132.4      0.0  192.0
#
#    Superplasticizer  Superplasticizer  Superplasticizer  Coarse Aggregate  \
# 0               2.5              6.25            15.625            1040.0
# 1               2.5              6.25            15.625            1055.0
# 2               0.0              0.00             0.000             932.0
# 3               0.0              0.00             0.000             932.0
# 4               0.0              0.00             0.000             978.4
#
#    Fine Aggregate  Age     Age       Age
# 0           676.0   28     784     21952
# 1           676.0   28     784     21952
# 2           594.0  270   72900  19683000
# 3           594.0  365  133225  48627125
# 4           825.5  360  129600  46656000

# %%
df.output=df.iloc[:,-1]
df.output.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Concrete compressive strength, dtype: float64

# %%
# Show columns containing missing values
print("Columns containing missing value:", 
      df.columns[df.isna().any()].tolist())
# Out:
# Columns containing missing value: []

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler

np_scaled = StandardScaler().fit_transform(df)
df = pd.DataFrame(np_scaled, columns=df.columns)
df.head()
# Out:
#      Cement    Cement    Cement  Blast Furnace Slag   Fly Ash     Water  \
# 0  2.477915  3.082741  3.656669           -0.856888 -0.847144 -0.916764
# 1  2.477915  3.082741  3.656669           -0.856888 -0.847144 -0.916764
# 2  0.491425  0.314795  0.138419            0.795526 -0.847144  2.175461
# 3  0.491425  0.314795  0.138419            0.795526 -0.847144  2.175461
# 4 -0.790459 -0.772458 -0.704732            0.678408 -0.847144  0.488793
#
#    Superplasticizer  Superplasticizer  Superplasticizer  Coarse Aggregate  \
# 0         -0.620448         -0.562020         -0.341847          0.863154
# 1         -0.620448         -0.562020         -0.341847          1.056164
# 2         -1.039143         -0.613752         -0.346795         -0.526517
# 3         -1.039143         -0.613752         -0.346795         -0.526517
# 4         -1.039143         -0.613752         -0.346795          0.070527
#
#    Fine Aggregate       Age       Age       Age  Concrete compressive strength
# 0       -1.217670 -0.279733 -0.261942 -0.206856                       2.645408
# 1       -1.217670 -0.279733 -0.261942 -0.206856                       1.561421
# 2       -2.240917  3.553066  3.310607  2.615418                       0.266627
# 3       -2.240917  5.057677  6.299042  6.770244                       0.313340
# 4        0.647884  4.978487  6.119464  6.487296                       0.507979

# %% [markdown]
# ### Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

inputNum = 14

X, y = df.iloc[:, 0:inputNum], df.iloc[:, inputNum:inputNum+1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
wName = ['w0', 'w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9', 'w10', 'w11', 'w12', 'w13', 'w14', 'w15', 'w16']
trainMSE = []
trainR2 = []

def descent3(X, y, dimension, w_current, learning_rate):
    w_gradient = np.zeros(dimension)
    N = float(X.shape[0])
    for i in range(0, X.shape[0]):
        x_data = X.iloc[i]
        y_data = y.iloc[i]
        #Calculating predicted value of model
        predicted = w_current[0]
        for j in range(1, X.shape[1]+1):
            predicted += w_current[j]*x_data[j-1]
        #Error value by model
        error = y_data[0] - predicted
        
        #Accumulating gradient from each 
        w_gradient[0] += -(2/N) * error
        for j in range(1, X.shape[1]+1):
            w_gradient[j] += -(2/N) * error * x_data[j-1]
    step_size = w_gradient * learning_rate
    new_w = w_current - step_size
    return new_w, step_size


def gd3(X, y, dimension, learning_rate=0.01, epochs=1000, stopThreshold = 0.000001):
    w_cur = np.random.uniform(-0.5,0.5,dimension)
    
    for i in range(epochs):
        w_cur, stepsize = descent3(X, y, dimension, w_cur, learning_rate)
        #y_pred_temp = y.copy.drop(index)
        
        Xcopy = X.copy()
        for j in range(dimension-1):
            Xcopy.iloc[:, j] *= w_cur[j+1]    
        y_pred_temp = Xcopy.sum(axis=1) + w_cur[0]
        
        mse = mean_squared_error(y, y_pred_temp)
        r2 = r2_score(y, y_pred_temp)
        
        trainMSE.append(mse)
        trainR2.append(r2)
        #print('w_cur:\n', w_cur, '\n----------\n')
        #print('step:\n', step, '\n----------\n')
        if all(abs(stepsize) < stopThreshold):
            print('prev_grad:\n', stepsize, '\n----------\n')
            print("epoch: ", i)
            break
    return w_cur

# %%
# use 8 attributes to train 
w_finish = gd3(X_train.iloc[:, :], y_train, 15)

# %%
w_finish = pd.DataFrame(w_finish.reshape((1,15)), columns=wName[:16])
w_finish

# %%
import seaborn as sns
import matplotlib.pyplot as plt
T = np.linspace(-1, max(trainMSE), len(trainMSE))
sns.scatterplot(x=T, y=trainMSE, label='Train MSE')
sns.scatterplot(x=T, y=trainR2, label='Train R2-score')

# %%
print("Init MSE: %f \nFinal MSE: %f" % (trainMSE[0], trainMSE[-1]))
print()
print("Init R2: %f \nFinal R2: %f" % (trainR2[0], trainR2[-1]))

# %% [markdown]
# ### Prediction

# %%
X_test2=X_test.iloc[:, 0:14].copy()

# %%
# w1X1, w2X2, ... , w8X8
for i in range(14):
    X_test2.iloc[:, i] *= w_finish.iloc[0, i+1]

# %%
# fit test data to our gd model

# (w1X1 + w2X2 + ... + w8X8) + w0
y_pred_gd3 = X_test2.sum(axis=1) + w_finish.iloc[0, 0]


#row = ['lm1', 'lm2', 'lm3', 'lm4', 'lm5', 'lm6', 'lm7', 'lm8']
col = ['MSE', 'Cor', 'R2', 'bias', 'weight']
regResult = pd.DataFrame(columns=col)
regResult.loc['gd3'] = mean_squared_error(y_test, y_pred_gd3), 0, r2_score(y_test, y_pred_gd3), \
                        w_finish.iloc[0, 0],  np.array(w_finish.iloc[0, 1:15])

# %%
regResult

# %%
import numpy as np
from sklearn import linear_model
clf = linear_model.SGDRegressor(max_iter=3000, tol=0.000001)
clf.fit(X_train, y_train)

y_pred_sgd = clf.predict(X_test)

print('Coefficients (weight): ', clf.coef_)
print('\nIntercept (bias): ', clf.intercept_)
print('SGD R2-score: ', r2_score(y_test, y_pred_sgd))
